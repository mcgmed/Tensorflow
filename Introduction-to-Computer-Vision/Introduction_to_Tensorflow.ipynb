# %% [markdown]
# <a href="https://colab.research.google.com/github/mcgmed/Tensorflow/blob/main/Introduction-to-Computer-Vision/Introduction_to_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

dense = Dense(units=1, input_shape=[1])
model = Sequential([dense])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
print("Here is what I learned: {}".format(dense.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 354ms/step - loss: 41.1680
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 32.7486
# Epoch 3/500
# 1/1 [==============================] - 0s 12ms/step - loss: 26.1173
# Epoch 4/500
# 1/1 [==============================] - 0s 14ms/step - loss: 20.8928
# Epoch 5/500
# 1/1 [==============================] - 0s 10ms/step - loss: 16.7754
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 13.5290
# Epoch 7/500
# 1/1 [==============================] - 0s 13ms/step - loss: 10.9681
# Epoch 8/500
# 1/1 [==============================] - 0s 12ms/step - loss: 8.9467
# Epoch 9/500
# 1/1 [==============================] - 0s 13ms/step - loss: 7.3498
# Epoch 10/500
# 1/1 [==============================] - 0s 13ms/step - loss: 6.0871
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0874
# Epoch 12/500
# ...

# %% [markdown]
# Thus, the learned relationship between X and Y was
#
# Y = 1.9967953X – 0.9900647.
